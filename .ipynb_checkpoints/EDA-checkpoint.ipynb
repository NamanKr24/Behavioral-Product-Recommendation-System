# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from data_loader import load_cosmetics_data

df = load_cosmetics_data()

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

print(df.head())
print("\nDataset Info:")
df.info()
# Out:
# Successfully loaded ./2019-Oct.csv
#                 event_time event_type  product_id          category_id  \
# 0  2019-10-01 00:00:00 UTC       cart     5773203  1487580005134238553
# 1  2019-10-01 00:00:03 UTC       cart     5773353  1487580005134238553
# 2  2019-10-01 00:00:07 UTC       cart     5881589  2151191071051219817
# 3  2019-10-01 00:00:07 UTC       cart     5723490  1487580005134238553
# 4  2019-10-01 00:00:15 UTC       cart     5881449  1487580013522845895
#
#   category_code   brand  price    user_id  \
# 0           NaN  runail   2.62  463240011
# 1           NaN  runail   2.62  463240011
# 2           NaN  lovely  13.48  429681830
# 3           NaN  runail   2.62  463240011
# 4           NaN  lovely   0.56  429681830
#
#                            user_session
# 0  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 1  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 2  49e8d843-adf3-428b-a2c3-fe8bc6a307c9
# 3  26dd6e6e-4dac-4778-8d2c-92e149dab885
# 4  49e8d843-adf3-428b-a2c3-fe8bc6a307c9
#
# Dataset Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025570 entries, 0 to 1025569
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   event_time     1025570 non-null  object
#  1   event_type     1025570 non-null  object
#  2   product_id     1025570 non-null  int64
#  3   category_id    1025570 non-null  int64
#  4   category_code  15760 non-null    object
#  5   brand          619540 non-null   object
#  6   price          1025570 non-null  float64
#  7   user_id        1025570 non-null  int64
#  8   user_session   1025485 non-null  object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 70.4+ MB

# %%
print("Missing values per column:")
print(df.isnull().sum())

print(f"\nNumber of duplicate rows: {df.duplicated().sum()}")
df.drop_duplicates(inplace=True)
print(f"Number of rows after dropping duplicates: {len(df)}")
# Out:
# Missing values per column:
# event_time             0
# event_type             0
# product_id             0
# category_id            0
# category_code    1009810
# brand             406030
# price                  0
# user_id                0
# user_session          85
# dtype: int64
#
# Number of duplicate rows: 55911
# Number of rows after dropping duplicates: 969659

# %%
df['event_time'] = pd.to_datetime(df['event_time'])
    
print("Data types after conversion:")
print(df.dtypes)
# Out:
# Data types after conversion:
# event_time       datetime64[ns, UTC]
# event_type                    object
# product_id                     int64
# category_id                    int64
# category_code                 object
# brand                         object
# price                        float64
# user_id                        int64
# user_session                  object
# dtype: object

# %%
numerical_cols = df.select_dtypes(include=np.number).columns.tolist()
ids_to_exclude = ['product_id', 'category_id', 'user_id']
numerical_cols_to_plot = [col for col in numerical_cols if col not in ids_to_exclude]

print(f"Plotting distributions for numerical columns: {numerical_cols_to_plot}")

for col in numerical_cols_to_plot:
    plt.figure(figsize=(10, 6))
    sns.histplot(df[col], kde=True, bins=50)
    plt.title(f'Distribution of {col}')
    plt.show()
# Out:
# Plotting distributions for numerical columns: ['price']

# %%
categorical_cols = df.select_dtypes(include='object').columns.tolist()

print(f"Plotting distributions for categorical columns: {categorical_cols}")

for col in categorical_cols:
    top_n = 15
    if df[col].nunique() > top_n:
        top_categories = df[col].value_counts().nlargest(top_n).index
        df_top = df[df[col].isin(top_categories)]
        
        plt.figure(figsize=(15, 8))
        sns.countplot(y=col, data=df_top, order=top_categories)
        plt.title(f'Top {top_n} Distribution of {col}')
        plt.xlabel('Count')
        plt.ylabel(col)
        plt.show()
    else:
        plt.figure(figsize=(12, 7))
        sns.countplot(y=col, data=df, order=df[col].value_counts().index)
        plt.title(f'Distribution of {col}')
        plt.xlabel('Count')
        plt.ylabel(col)
        plt.show()
# Out:
# Plotting distributions for categorical columns: ['event_type', 'category_code', 'brand', 'user_session']

# %%
plt.figure(figsize=(10, 6))
sns.countplot(x='event_type', data=df, order=df['event_type'].value_counts().index)
plt.title('Distribution of Event Types')
plt.xlabel('Event Type')
plt.ylabel('Count')
plt.show()

print(df['event_type'].value_counts())
# Out:
# event_type
# view                431548
# cart                358103
# remove_from_cart    125751
# purchase             54257
# Name: count, dtype: int64

# %%
purchases_df = df[df['event_type'] == 'purchase']
    
top_10_products = purchases_df['product_id'].value_counts().head(10)

print("Top 10 Most Purchased Products:")
print(top_10_products)

plt.figure(figsize=(12, 7))
sns.barplot(x=top_10_products.index.astype(str), y=top_10_products.values, hue=top_10_products.index.astype(str), palette='viridis', legend=False)
plt.title('Top 10 Most Purchased Products')
plt.xlabel('Product ID')
plt.ylabel('Number of Purchases')
plt.xticks(rotation=45)
plt.show()
# Out:
# Top 10 Most Purchased Products:
# product_id
# 5700037    162
# 5751422    155
# 5792800    150
# 5854897    147
# 5688124    141
# 5809912    133
# 5802432    123
# 5751383    120
# 5892179    106
# 5773361    102
# Name: count, dtype: int64

# %%
funnel_data = df.groupby('event_type')['user_id'].nunique().sort_values(ascending=False)
    
funnel_data = funnel_data.reindex(['view', 'cart', 'purchase'])

print("User Funnel:")
print(funnel_data)

view_to_cart_rate = funnel_data['cart'] / funnel_data['view'] * 100
cart_to_purchase_rate = funnel_data['purchase'] / funnel_data['cart'] * 100

print(f"\nConversion Rate (View to Cart): {view_to_cart_rate:.2f}%")
print(f"Conversion Rate (Cart to Purchase): {cart_to_purchase_rate:.2f}%")

plt.figure(figsize=(10, 6))
sns.barplot(x=funnel_data.index, y=funnel_data.values, hue = funnel_data.index, palette='plasma', legend=False)
plt.title('User Conversion Funnel')
plt.xlabel('Event Type')
plt.ylabel('Number of Unique Users')
plt.show()
# Out:
# User Funnel:
# event_type
# view        131144
# cart         69624
# purchase      6260
# Name: user_id, dtype: int64
#
# Conversion Rate (View to Cart): 53.09%
# Conversion Rate (Cart to Purchase): 8.99%

# %%
top_10_brands = df['brand'].dropna().value_counts().head(10).index.tolist()
    
df_top_brands = df[df['brand'].isin(top_10_brands)]

plt.figure(figsize=(15, 8))
sns.countplot(x='brand', hue='event_type', data=df_top_brands, 
              order=top_10_brands, hue_order=['view', 'cart', 'purchase'])
plt.title('Event Distribution for Top 10 Brands')
plt.xlabel('Brand')
plt.ylabel('Count of Events')
plt.xticks(rotation=45)
plt.legend(title='Event Type')
plt.show()

# %%
price_cap = df['price'].quantile(0.99)
df_filtered_price = df[df['price'] < price_cap]

plt.figure(figsize=(12, 8))
sns.boxplot(x='event_type', y='price', data=df_filtered_price, 
            order=['view', 'cart', 'purchase'])
plt.title('Price Distribution by Event Type (Outliers Removed)')
plt.xlabel('Event Type')
plt.ylabel('Price')
plt.show()
